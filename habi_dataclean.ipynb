# %% [markdown]
# <a href="https://colab.research.google.com/github/PedrobVuninorte/APP_Movil/blob/main/habi_dataclean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-d3d200e3-895d-4a77-9228-0b5fd81ea52e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d3d200e3-895d-4a77-9228-0b5fd81ea52e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data_FIFA.csv to data_FIFA (4).csv

# %%
import io
df=pd.read_csv(io.BytesIO(uploaded['data_FIFA.csv']))

# %%
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age Nationality  Overall  Potential  \
# 0           0  158023           L. Messi   31   Argentina       94         94
# 1           1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2           2  190871          Neymar Jr   26      Brazil       92         93
# 3           3  193080             De Gea   27       Spain       91         93
# 4           4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value   Wage  ...  Composure Marking  \
# 0         FC Barcelona  €110.5M  €565K  ...       96.0    33.0
# 1             Juventus     €77M  €405K  ...       95.0    28.0
# 2  Paris Saint-Germain  €118.5M  €290K  ...       94.0    27.0
# 3    Manchester United     €72M  €260K  ...       68.0    15.0
# 4      Manchester City    €102M  €355K  ...       88.0    68.0
#
#    StandingTackle  SlidingTackle  GKDiving GKHandling GKKicking GKPositioning  \
# ...

# %%
df.shape
# Out:
# (18207, 86)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 86 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Nationality               18207 non-null  object
#  5   Overall                   18207 non-null  int64
#  6   Potential                 18207 non-null  int64
#  7   Club                      17966 non-null  object
#  8   Value                     18207 non-null  object
#  9   Wage                      18207 non-null  object
#  10  Special                   18207 non-null  int64
#  11  Preferred Foot            18159 non-null  object
#  12  International Reputation  18159 non-null  float64
# ...

# %%
df = df.set_index('ID')

# %%
#Realizar un proceso de limpieza del dataset
#Drop unamed column
df = df.drop('Unnamed: 0',axis=1)

# %%
df.head()
# Out:
#                      Name  Age Nationality  Overall  Potential  \
# ID
# 158023           L. Messi   31   Argentina       94         94
# 20801   Cristiano Ronaldo   33    Portugal       94         94
# 190871          Neymar Jr   26      Brazil       92         93
# 193080             De Gea   27       Spain       91         93
# 192985       K. De Bruyne   27     Belgium       91         92
#
#                        Club    Value   Wage  Special Preferred Foot  ...  \
# ID                                                                   ...
# 158023         FC Barcelona  €110.5M  €565K     2202           Left  ...
# 20801              Juventus     €77M  €405K     2228          Right  ...
# 190871  Paris Saint-Germain  €118.5M  €290K     2143          Right  ...
# 193080    Manchester United     €72M  €260K     1471          Right  ...
# 192985      Manchester City    €102M  €355K     2281          Right  ...
#
# ...

# %%
#Find if exists columns with  NaN values, list them and replace values with 0
df.columns[df.isna().any()].tolist()
# Out:
# ['Club',
#  'Preferred Foot',
#  'International Reputation',
#  'Weak Foot',
#  'Skill Moves',
#  'Work Rate',
#  'Body Type',
#  'Real Face',
#  'Position',
#  'Jersey Number',
#  'Joined',
#  'Loaned From',
#  'Contract Valid Until',
#  'Height',
#  'Weight',
#  'LS',
#  'ST',
#  'RS',
#  'LW',
#  'LF',
#  'CF',
#  'RF',
#  'RW',
#  'LAM',
#  'CAM',
#  'RAM',
#  'LM',
#  'LCM',
#  'CM',
#  'RCM',
#  'RM',
#  'LWB',
#  'LDM',
#  'CDM',
#  'RDM',
#  'RWB',
#  'LB',
#  'LCB',
#  'CB',
#  'RCB',
#  'RB',
#  'Crossing',
#  'Finishing',
#  'HeadingAccuracy',
#  'ShortPassing',
#  'Volleys',
#  'Dribbling',
#  'Curve',
#  'FKAccuracy',
#  'LongPassing',
#  'BallControl',
#  'Acceleration',
#  'SprintSpeed',
#  'Agility',
#  'Reactions',
#  'Balance',
#  'ShotPower',
#  'Jumping',
#  'Stamina',
#  'Strength',
#  'LongShots',
#  'Aggression',
#  'Interceptions',
#  'Positioning',
#  'Vision',
#  'Penalties',
#  'Composure',
#  'Marking',
#  'StandingTackle',
#  'SlidingTackle',
# ...

# %%
#create list with non object columns 
positions = ['LS',
 'ST',
 'RS',
 'LW',
 'LF',
 'CF',
 'RF',
 'RW',
 'LAM',
 'CAM',
 'RAM',
 'LM',
 'LCM',
 'CM',
 'RCM',
 'RM',
 'LWB',
 'LDM',
 'CDM',
 'RDM',
 'RWB',
 'LB',
 'LCB',
 'CB',
 'RCB',
 'RB',
 ]

#clean NaN in dataframe
def fill_na(df):
  for col in df:
    if (df.dtypes[col] == np.int64):
          df[col].fillna(0,inplace=True)
    elif (df.dtypes[col] ==np.float64):
          df[col].fillna(0,inplace=True)
    else: 
      if df[col].name in positions:
        df[col].fillna(0,inplace=True)
        df[col].replace('nan',0,inplace=True)
      else:
        df[col].replace(np.nan,"Undefined",inplace=True)

fill_na(df)

# %%
#Sum values in position columns
def sum_pos(df):
  for col in df: 
    if df[col].name in positions:
      df[col + "_unit"]=df[col].map(pd.eval)
sum_pos(df)

# %%
def drop_columns (df):
  for col in df: 
    if df[col].name in positions:
      df.drop(col,axis=1)
drop_columns(df)

# %%
df.head(11)
# Out:
#                      Name  Age Nationality  Overall  Potential  \
# ID
# 158023           L. Messi   31   Argentina       94         94
# 20801   Cristiano Ronaldo   33    Portugal       94         94
# 190871          Neymar Jr   26      Brazil       92         93
# 193080             De Gea   27       Spain       91         93
# 192985       K. De Bruyne   27     Belgium       91         92
# 183277          E. Hazard   27     Belgium       91         91
# 177003          L. Modrić   32     Croatia       91         91
# 176580          L. Suárez   31     Uruguay       91         91
# 155862       Sergio Ramos   32       Spain       91         91
# 200389           J. Oblak   25    Slovenia       90         93
# 188545     R. Lewandowski   29      Poland       90         90
#
#                        Club  Value  Wage  Special Preferred Foot  ...  \
# ID                                                                ...
# ...

# %%
df['Value'] = df['Value'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int) #Extract value 
df['Wage'] = df['Wage'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int) #Extract wage
df['Release Clause'] = df['Release Clause'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int) #Extract release clause value

# %%
fill_na(df)

# %%
df['Value_M']=df['Value']*100000
df['Wage_K']=df['Wage']*1000
df['Release_M']=df['Release Clause']*100000

# %%
df['Value_M']=df['Value_M'].astype(float)
df['Wage_K']=df['Wage_K'].astype(float)
df['Release_M']=df['Release_M'].astype(float)
df.head
# Out:
# <bound method NDFrame.head of                       Name  Age Nationality  Overall  Potential  \
# ID
# 158023            L. Messi   31   Argentina       94         94
# 20801    Cristiano Ronaldo   33    Portugal       94         94
# 190871           Neymar Jr   26      Brazil       92         93
# 193080              De Gea   27       Spain       91         93
# 192985        K. De Bruyne   27     Belgium       91         92
# ...                    ...  ...         ...      ...        ...
# 238813        J. Lundstram   19     England       47         65
# 243165  N. Christoffersson   19      Sweden       47         63
# 241638           B. Worman   16     England       47         67
# 246268      D. Walker-Rice   17     England       47         66
# 246269           G. Nugent   16     England       46         66
#
#                        Club  Value  Wage  Special Preferred Foot  ...  \
# ID                                                                ...
# ...

# %%
#Identificar el top 5 de jugadores de mejores salarios, valoración general y potencial.
top5_overall = df.sort_values(by="Overall", ascending=False).head(5)
top5_overall
# Out:
#                      Name  Age Nationality  Overall  Potential  \
# ID
# 158023           L. Messi   31   Argentina       94         94
# 20801   Cristiano Ronaldo   33    Portugal       94         94
# 190871          Neymar Jr   26      Brazil       92         93
# 193080             De Gea   27       Spain       91         93
# 192985       K. De Bruyne   27     Belgium       91         92
#
#                        Club  Value  Wage  Special Preferred Foot  ...  \
# ID                                                                ...
# 158023         FC Barcelona   1105   565     2202           Left  ...
# 20801              Juventus     77   405     2228          Right  ...
# 190871  Paris Saint-Germain   1185   290     2143          Right  ...
# 193080    Manchester United     72   260     1471          Right  ...
# 192985      Manchester City    102   355     2281          Right  ...
#
#         RDM_unit  RWB_unit  LB_unit LCB_unit CB_unit RCB_unit RB_unit  \
# ID
# ...

# %%
top5_potencial = df.sort_values(by="Potential", ascending=False).head(5)
top5_potencial
# Out:
#                      Name  Age Nationality  Overall  Potential  \
# ID
# 231747          K. Mbappé   19      France       88         95
# 158023           L. Messi   31   Argentina       94         94
# 211110          P. Dybala   24   Argentina       89         94
# 20801   Cristiano Ronaldo   33    Portugal       94         94
# 190871          Neymar Jr   26      Brazil       92         93
#
#                        Club  Value  Wage  Special Preferred Foot  ...  \
# ID                                                                ...
# 231747  Paris Saint-Germain     81   100     2118          Right  ...
# 158023         FC Barcelona   1105   565     2202           Left  ...
# 211110             Juventus     89   205     2092           Left  ...
# 20801              Juventus     77   405     2228          Right  ...
# 190871  Paris Saint-Germain   1185   290     2143          Right  ...
#
#         RDM_unit  RWB_unit  LB_unit LCB_unit CB_unit RCB_unit RB_unit  \
# ID
# ...

# %%
top5_wage = df.sort_values(by="Wage_K", ascending=False).head(5)
top5_wage
# Out:
#                      Name  Age Nationality  Overall  Potential          Club  \
# ID
# 158023           L. Messi   31   Argentina       94         94  FC Barcelona
# 176580          L. Suárez   31     Uruguay       91         91  FC Barcelona
# 177003          L. Modrić   32     Croatia       91         91   Real Madrid
# 20801   Cristiano Ronaldo   33    Portugal       94         94      Juventus
# 155862       Sergio Ramos   32       Spain       91         91   Real Madrid
#
#         Value  Wage  Special Preferred Foot  ...  RDM_unit  RWB_unit  LB_unit  \
# ID                                           ...
# 158023   1105   565     2202           Left  ...        63        66       61
# 176580     80   455     2346          Right  ...        73        74       71
# 177003     67   420     2280          Right  ...        84        85       82
# 20801      77   405     2228          Right  ...        64        68       64
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Jugadores con características atípicas dentro de la muestra con respecto a salarios o edad, etc.
# Con respecto a la EDAD
plt.boxplot(df['Age'], vert=False)
plt.show()

# %%
#Detectamos los quartiles y rango inter quartil para el analisis
Q1= df['Age'].quantile(0.25)
Q3= df['Age'].quantile(0.75)
IQR= Q3-Q1
Mediana= df['Age'].median()
VMin= df['Age'].min()
VMAx= df['Age'].max()
print('Primer Cuartil',Q1)
print('Tercer Cuartil',Q3)
print('Rango',IQR)
print('Mediana',Mediana)
print('Valor Minimo',VMin)
print('Valor Maximo',VMAx)
# Out:
# Primer Cuartil 21.0
# Tercer Cuartil 28.0
# Rango 7.0
# Mediana 25.0
# Valor Minimo 16
# Valor Maximo 45

# %%
#Limites inferio y superior
LI=int(Q1-1.5*IQR)
LS=int(Q3+ 1.5*IQR)
print(LI,LS)
# Out:
# 10 38

# %%
#Datos atipicos de juagdores los cuales sobrepasan el rango superior de Edad
Atipicos= (df['Age']> LS)
df[Atipicos].sort_values('Age')
# Out:
#                       Name  Age        Nationality  Overall  Potential  \
# ID
# 49212           J. Speroni   39          Argentina       68         68
# 152690  D. Konstantopoulos   39             Greece       64         64
# 146636           José Juan   39              Spain       68         68
# 136553       Lee Dong Gook   39     Korea Republic       68         68
# 182461           Zhou Ting   39           China PR       52         52
# 159436           R. Zapata   39           Colombia       69         69
# 156662           A. Bastía   39          Argentina       70         70
# 105308           J. Gillet   39            Belgium       70         70
# 142670            R. Braña   39          Argentina       70         70
# 142818           F. Cubero   39          Argentina       71         71
# 16097           N. Rimando   39      United States       71         71
# 53352            D. Bulman   39            England       60         60
# ...

# %%
df2= df[['Club','Name','Age','Wage','Wage_K']]
df2
# Out:
#                        Club                Name  Age  Wage    Wage_K
# ID
# 158023         FC Barcelona            L. Messi   31   565  565000.0
# 20801              Juventus   Cristiano Ronaldo   33   405  405000.0
# 190871  Paris Saint-Germain           Neymar Jr   26   290  290000.0
# 193080    Manchester United              De Gea   27   260  260000.0
# 192985      Manchester City        K. De Bruyne   27   355  355000.0
# ...                     ...                 ...  ...   ...       ...
# 238813      Crewe Alexandra        J. Lundstram   19     1    1000.0
# 243165       Trelleborgs FF  N. Christoffersson   19     1    1000.0
# 241638     Cambridge United           B. Worman   16     1    1000.0
# 246268      Tranmere Rovers      D. Walker-Rice   17     1    1000.0
# 246269      Tranmere Rovers           G. Nugent   16     1    1000.0
#
# [18207 rows x 5 columns]
